# %% [markdown]
# # MY JUPITER NOTEBOOK ON IBM WATSON STUDIO

# %% [markdown]
# **My name is Mohit**
# I am currently a student and I want to work as data scientist or analyst for an organization.

# %% [markdown]
# *I want to be data scientist for numerous reason. One is that data is being produced every second. And with that data companies make revenue and we can also by being part of it make good amount of money.*

# %% [markdown]
# # In the code below two numbers are being added.

# %%
print(3*4*5*6*7*8*9)
# Out:
# 181440

# %% [markdown]
# 1. It was easy to implement
# 2. Cant wait to learn more
# 3. It is quite clear to me now
#
# WEBSITE LINK - (http://ibm.com/)
#
# FOR MORE INFORMATION
#
# ![ibm.jpeg](attachment:d2cd82e0-9494-41f8-917a-bbd64a9ba357.jpeg)
